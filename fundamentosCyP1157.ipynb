# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoArroyo12/CompYProg2022G1157/blob/main/fundamentosCyP1157.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = 'Jose' # Tipo de dat String (cadena de caracteres)

print(nombre)
# Out:
# Jose

# %% [markdown]
# # Tipos de dato en Python
#
# - str --> String cadena de caracteres.
# - int --> Números enteros
# - float --> Números con notación de punto flotante.
# - complex --> Números complejos
# - bool --> Boleano ( True o False )
# -byte --> 8 bits
#
# ### Tipos de datos estructurados (compuestos)
#
#
# - list --> Listas (Arreglos en otros leng)
# - tuple --> Listas no mutables
# - dict --> diccionarios
# - set y frozenset --> Comjuntos

# %%
import sys 

edad = 19 
print( "Tu edad es:",edad )  # al final de una línea de código 
# este es un comentario de línea simple

"""
Comentario de múltiple línea 
En lenguaje C, C++ y Java el comentario de múltipk¿le línea es con: /* ..... */

En lenguaje C, C++ y Java el comentario de una sola línea es con: //

Aquí puedes axplicar en prosa el segmento de un código para futura revisión 

"""
# tipos de datos numérico  int y float 

print ( sys.getsizeof(edad) )
# el tipo de dato INT utiliza diferente cantidad de bits segun el leg de prog.
# por ejemolo en C utiliza 16 bits. 

edad = edad + 1 

print ( edad )

estatura = 1.56
print( estatura )
print(sys.getsizeof(estatura))
estatura = estatura + 0.1
print( estatura )
print( round(estatura,2) )

edad += 1 #edad = edad + 1 
print( "Tu edad es:",edad )

edad -= 1 #edad = edad - 1 
print( "Tu edad es:",edad )

edad += 1 # vulve a 21 
edad /= 2 #edad = edad / 2
print( "La mitad de tu edad es:",edad )


edad = 21 
# volver a calcular la mitad de la edad pero solo dejar parte entera 
edad = edad // 2 
print( "La mitad de tu edad es:",edad )

# En la mayoría de los leng no permite operaciones entre diferentes tipos de 
# datos, en python no es el caso 

numero = edad / 2.0 
print( numero )

numero = numero * 3 # numero *= 3 
print( numero )

numero = 5.0 
numero = numero ** 3 # numero **= 2 en python no en todos los lenguajes 
print( numero )

# operador módulo 
numero = 21
print( numero /2 )
print( numero // 2 )

# el operador modulo da como resultado el residuo de una división 
print( numero % 2 )
# Out:
# Tu edad es: 19
# 28
# 20
# 1.56
# 24
# 1.6600000000000001
# 1.66
# Tu edad es: 21
# Tu edad es: 20
# La mitad de tu edad es: 10.5
# La mitad de tu edad es: 10
# 5.0
# 15.0
# 125.0
# 10.5
# 10
# 1

# %%
numero = 24 
print( "Residuo de 24 / 5 es:", numero % 5)
# operadores relacionales (lógicos)
print( numero % 2 == 0)
print( numero <= 6 * 4)

# diferencia 
print("24 es diferente de 23=" , numero != 23)

print("24 es mayor que 23=", numero > 23)

print("El tipo de dato de la variable numero es:",type(numero))
print("El tipo de dato de la variable numero es:",type(numero/2.0))
# Out:
# Residuo de 24 / 5 es: 4
# True
# True
# 24 es diferente de 23= True
# 24 es mayor que 23= True
# El tipo de dato de la variable numero es: <class 'int'>
# El tipo de dato de la variable numero es: <class 'float'>

# %% [markdown]
# # Tipo de dato String (str) en Python
# - Se maneja como un arreglo (tipo de dato compuesto)
# - Se puede acceder a los elementos de el dtring por medio del índice del caracter.
# - Mutable
# -Tiene métodos útiles (potentes)
# - Slicing

# %%
nombre = "diego" # hay 4 formas se pueden usar comillas 
carrera = "Ingeniería en Computación"
frase = """ El conocimiento 
me persigue,...
pero 
yo soy más rápido 
"""
print(nombre)
print(carrera)
print(frase)

# La funcion type de Python te devulve el tipo de una variable o expresión 
print( type(nombre))

paterno = str("Arroyo")
print( paterno )
# Out:
# diego
# Ingeniería en Computación
#  El conocimiento
# me persigue,...
# pero
# yo soy más rápido
#
# <class 'str'>
# Arroyo

# %% [markdown]
# #Una clase (class) es un tipo de dato compuesto

# %%
carrera = "Ingeniería en computación" 
print ( carrera )
print ( carrera[2])
# Out:
# Ingeniería en computación
# g

# %% [markdown]
# # A la sintaxis escrita para elegir en elemento de un grupo se datos se le llama selector.
#
# En el caso de Strings y listas (lst) sr usan los caracteres '[ ' y ' ]
#
# 1. En todos los lengiajes los arreglos inician en 0.
# 2. En python no existe como tal el tipo de dato arreglo, el concepto es listas.
# 3. Los strings se comportan como un arreglo en la mayoría de los lenguajes.
# 4. En python se acepta en indexado negativo, en otros lenguajes NO.

# %%
carrera = "Ingeniería en computación"
print( carrera[8] )
print( carrera[24] )
print( carrera[-1] )
print( carrera[-25] )


# Adelante el tema ciclo FOR

for letra in carrera: 
    print( "-->" , letra , "<--")
# Out:
# í
# n
# n
# I
# --> I <--
# --> n <--
# --> g <--
# --> e <--
# --> n <--
# --> i <--
# --> e <--
# --> r <--
# --> í <--
# --> a <--
# -->   <--
# --> e <--
# --> n <--
# -->   <--
# --> c <--
# --> o <--
# --> m <--
# --> p <--
# --> u <--
# --> t <--
# --> a <--
# --> c <--
# --> i <--
# --> ó <--
# --> n <--

# %% [markdown]
# # Slicing (rebanado) de cadenas
#
# Permite seleccionar subcadenas con el operador
# ####[incio : stop : incremento]
# El stop no se incluye es por eso que debemos agregar una posición extra
#
# ### Slicing y valores por defecto
#
# Inicio por defecto siempre será 0 stop: tamaño del arreglo (indexado positivo)
#
# Incremento: es 1 (indexado positivo)

# %%
carrera = "Ingeniería en computación"
print( carrera[0:10:1] )
print( carrera[14:25:1] )
# lo mismo pero con indexado negativo ??
print( carrera [ -11 :  : 1])
print( carrera[:10:]) 

print("-----------")
# un ejercicio mas para ver incremento 
print( carrera[0:10:2] ) 
print( carrera[-1:-12:-1])
# Out:
# Ingeniería
# computación
# computación
# Ingeniería
# -----------
# Igneí
# nóicatupmoc

# %% [markdown]
# # String y sus métodos
# # Todos los tipos de datos en python son objetos de la POO
# Lo cual significa que tienen atributos y métodos
# ## dir() y help() son funciones para obtener ayuda del lenguaje python
#
# ### dir muestra las funciones de un tipo de dato como resumen help muestra la misma ayuda pero a detalle.
#
#
# Metodo que inician con doble guion bajo son privados de uso interno de deberiamos usarlos }
# Todos los demas son para uso exterior (usuario)

# %%
frutas = " limon , fresa, manzana , aguacate "
nombre = "diego"
print( frutas )
dir(frutas)

print( nombre.capitalize() )
print( nombre.upper() )
print( frutas. replace( 'a' , '4').replace('e','3').upper()	 )
frutas = frutas. replace( 'a' , '4').replace('e','3').upper()
print( frutas )

frutas = " limon , fresa, manzana , aguacate "
print( frutas.strip() )
print( frutas.split(',') )
print( frutas.index("n") )
print( frutas.find("f"))
# Out:
#  limon , fresa, manzana , aguacate
# Diego
# DIEGO
#  LIMON , FR3S4, M4NZ4N4 , 4GU4C4T3
#  LIMON , FR3S4, M4NZ4N4 , 4GU4C4T3
# limon , fresa, manzana , aguacate
# [' limon ', ' fresa', ' manzana ', ' aguacate ']
# 5
# 9

# %% [markdown]
# # String y caracteres de escape
#
# - \\"   --> "
# - \\'   --> '
# - \n   --> Salto de linea (tecla enter)
# - \t   --> tabulador spacios a la izq.
# - \uxxxx  --> Caracteres unicode 16 bits (2 bytes)
# - \Uxxxxxxxx --> unicode extendido 4 bytes
# - \\\   --> \\

# %%
print("\"Diego\"")
nombre = "\"Diego\""
print( nombre )
carrera = "Ingeniería \n\t en \n\t\tComputación"
print( carrera )
print("\u0065")
print("\u0444")
print("\u0620")

print("\U00010057")
print("\U0001F60E")
print("\U0001F9A0")
# Out:
# "Diego"
# "Diego"
# Ingeniería
# 	 en
# 		Computación
# e
# ф
# ؠ
# 𐁗
# 😎
# 🦠

# %% [markdown]
# # Función print
#
# ### Se emplea para desplegar información en la salida estandar. Normalmente en un monitor.
#
# - Formas de udar print
# - El argumento por defecto de print (end)
# - format()
# - oprador f" "

# %%
nombre = "Diego" 
edad = 18 
casado = False 
estatura = 1.70

"""
 Nombre: Jose 
  Edad: 18
  Esta casado: False 
  Estatura en metros: 1.70
"""
#1.- con comas.- concatena haciendo un casting (conversion a string automaticamente)
# agrega un espacio 
print( nombre , edad , casado , estatura )
print("Nombre: " + nombre + "\n\tEdad: " + str(edad) + "\n\tEsta casado: " + str(casado) + "\n\tEstatura en metros: " + str(estatura))

# 2.- con el símbolo de "+"
# Concatenación en crudo 
print( nombre + " " + str(edad) + " " + str(casado) + " " + str(estatura) )

# 3.- dando formato a la salida con format()
print("\nCon la fucion format()")
print("Nombre : {3}\n\tEdad: {2}\n\tEsta casado: {1}\n\tEstatura en metros: {0}".format(nombre,edad,casado,estatura))

#4.- con el operador f" 
print("\nCon el operador f\" \"") 
print(f"Nombre : { nombre }\n\tEdad: { edad }\n\tEsta casado: { casado }\n\tEstatura en metros: { estatura }")


# Como manejar el argumento end 
print("\n Como usar el argumento end")
print(f"Hola { nombre }" , end="")
print(", Como estas?" , end="\n")
# Out:
# Diego 18 False 1.7
# Nombre: Diego
# 	Edad: 18
# 	Esta casado: False
# 	Estatura en metros: 1.7
# Diego 18 False 1.7
#
# Con la fucion format()
# Nombre : 1.7
# 	Edad: False
# 	Esta casado: 18
# 	Estatura en metros: Diego
#
# Con el operador f" "
# Nombre : Diego
# 	Edad: 18
# 	Esta casado: False
# 	Estatura en metros: 1.7
#
#  Como usar el argumento end
# Hola Diego, Como estas?

# %% [markdown]
# # Con una sola funcion POR LETRA print, escribri su primer nombre (nombre de pila) de la siguiente forma
#
# DD        DDDDDDD
# D  D         D
# D    D       D
# D     D      D
# D     D      D
# D    D       D
# D   D        D
# D  D         D
# DD        DDDDDDD

# %%
print("DIEGO")
# Out:
# DIEGO
